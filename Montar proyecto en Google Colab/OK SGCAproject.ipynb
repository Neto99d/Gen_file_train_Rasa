# %% [markdown]
# Clonar el proyecto

# %%
# !git clone https://github.com/Neto99d/Gen_file_train_Rasa.git

# %% [markdown]
# Usar directorio del proyecto

# %%
cd Gen_file_train_Rasa/

# %% [markdown]
# usar rama *fullES* (Esta rama usa los modelos preentrenados en español para preguntas y respuestas, además de los otros algoritmos, pero el que esta por defecto es el del modelo preentrenado.)
#
# Para cambiar ir al archivo cargarDatos.py
# y en la opcion 2 comentar la version 3 y descomentar la version 2 que usa modelo Respuestas y similitud entre oraciones, procesamiento lenguaje natural Spacy para entidades nombradas.

# %%
# !git checkout develop_neto_FullES

# %% [markdown]
# Instalar requerimientos (No alarmarse si al final salen letras en rojo y quiza pida reiniciar con un boton que sale debajo)

# %% [markdown]
# Donde buscar los enlaces a los modelos Spacy español con v3.4.0 por si estos dan error de instalación, buscar la opcion DOWNLOAD LINK y al lado clic derecho y copiar enlace del archivo, sustituir por el que esta puesto.
#
# Modelos:
# es_core_news_md y es_core_news_lg
#
# https://spacy.io/models/es
#
# Para Spacy 3.4.0 (ultimo hasta el momento)

# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/es_core_news_md-3.4.0/es_core_news_md-3.4.0-py3-none-any.whl

# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/es_core_news_lg-3.4.0/es_core_news_lg-3.4.0-py3-none-any.whl

# %%
# !pip install -r requirements.txt

# %%
# !pip install tensorflow==2.9

# %% [markdown]
# En caso de reiniciar volver a cargar el directorio Gen_file_train_Rasa

# %%
cd Gen_file_train_Rasa/

# %% [markdown]
# Instalr mongoDB e iniciar servicio

# %%
# !apt-get install mongodb

# %%
# !service mongodb start

# %% [markdown]
# Iniciar proyecto

# %% [markdown]
# Primero accedemos al directorio del código fuente (carpeta src), luego iniciamos el sistema

# %%
cd src

# %%
# !python systemSGCA.py
